# %%
import pandas as pd

# %%
df = pd.read_csv("prices-of-comodies.csv")

# %%
df
# Out:
#   Product name  prices  Quantity First name  last name
# 0      Mangoes       2        20      Kafui     Anyomi
# 1       Apples       5       100     Alfred  Ayi-Bonte
# 2      Oranges       3       200       Kofi      Green
# 3          Yam      10         5      Kosua     Selasi
# 4       onions       2       100        Ama      Adjoa
# 5   Pineapples       5        10      Kwame      Bonte
# 6       Pawpaw       5        20    Kwabena      james
# 7         rice     300         1      Adjei       Scot
# 8         pear       5        50        Afi     Abebum

# %%
df["Full name"] = df["First name"] + " " + df["last name"]

# %%
df
# Out:
#   Product name  prices  Quantity First name  last name         Full name
# 0      Mangoes       2        20      Kafui     Anyomi      Kafui Anyomi
# 1       Apples       5       100     Alfred  Ayi-Bonte  Alfred Ayi-Bonte
# 2      Oranges       3       200       Kofi      Green        Kofi Green
# 3          Yam      10         5      Kosua     Selasi      Kosua Selasi
# 4       onions       2       100        Ama      Adjoa         Ama Adjoa
# 5   Pineapples       5        10      Kwame      Bonte       Kwame Bonte
# 6       Pawpaw       5        20    Kwabena      james     Kwabena james
# 7         rice     300         1      Adjei       Scot        Adjei Scot
# 8         pear       5        50        Afi     Abebum        Afi Abebum

# %%
df['Revenue'] = df['Quantity'] * df['prices']

# %%
df
# Out:
#   Product name  prices  Quantity First name  last name         Full name  \
# 0      Mangoes       2        20      Kafui     Anyomi      Kafui Anyomi
# 1       Apples       5       100     Alfred  Ayi-Bonte  Alfred Ayi-Bonte
# 2      Oranges       3       200       Kofi      Green        Kofi Green
# 3          Yam      10         5      Kosua     Selasi      Kosua Selasi
# 4       onions       2       100        Ama      Adjoa         Ama Adjoa
# 5   Pineapples       5        10      Kwame      Bonte       Kwame Bonte
# 6       Pawpaw       5        20    Kwabena      james     Kwabena james
# 7         rice     300         1      Adjei       Scot        Adjei Scot
# 8         pear       5        50        Afi     Abebum        Afi Abebum
#
#    Revenue
# 0       40
# 1      500
# 2      600
# 3       50
# 4      200
# 5       50
# 6      100
# 7      300
# 8      250

# %%
df.mean()
# Out:
# prices       37.444444
# Quantity     56.222222
# Revenue     232.222222
# dtype: float64

# %%
df.apply()
